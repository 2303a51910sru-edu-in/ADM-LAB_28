# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51910sru-edu-in/ADM-LAB_28/blob/main/ADM_1910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
s=pd.Series([12,1,5,3,2])
print(s)
# Out:
# 0    12
# 1     1
# 2     5
# 3     3
# 4     2
# dtype: int64

# %%
ds1 = pd.Series([5,6,9,8,1])
ds2 = pd.Series([12,4,-1,5,3])
print('Sum of series Element')
ds= ds1 + ds2
print(ds)
print('Product of series Element')
ds= ds1 * ds2
print(ds)
print('Difference of series Element')
ds= ds1 - ds2
print(ds)
# Out:
# Sum of series Element
# 0    17
# 1    10
# 2     8
# 3    13
# 4     4
# dtype: int64
# Product of series Element
# 0    60
# 1    24
# 2    -9
# 3    40
# 4     3
# dtype: int64
# Difference of series Element
# 0    -7
# 1     2
# 2    10
# 3     3
# 4    -2
# dtype: int64

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
data = pd.read_csv('banklist.csv')
data.head()
# Out:
#      <input type="file" id="files-ce99d0b9-11c1-46fb-b7a5-06a30e9f25d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce99d0b9-11c1-46fb-b7a5-06a30e9f25d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
data = pd.read_csv('banklist.csv')
print(data.isnull().sum())
# Out:
#      <input type="file" id="files-05f4697b-10ad-4952-b51c-4072c9b12faa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05f4697b-10ad-4952-b51c-4072c9b12faa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
data = pd.read_csv('titanic.csv')
print(data.isnull().sum())
# Out:
#      <input type="file" id="files-7b3b88cc-bbfc-4aab-a292-c13de2c292f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b3b88cc-bbfc-4aab-a292-c13de2c292f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

from google.colab import files

# Upload a file manually
uploaded = files.upload()

df1 = pd.read_csv('Diabetes Missing Data.csv')
print("Original DataFrame with missing values:")
print(df1.info())
print(df1.isnull().sum())

if 'BMI' in df1.columns:
    df1['BMI'] = df1['BMI'].fillna(df1['BMI'].mean())

    if 'skin_Fold' in df1.columns:
        df1['skin_Fold'] = df1['skin_Fold'].fillna(df1['skin_Fold'].median())

        if 'Glucose' in df1.columns:
            df1['Glucose'] = df1['Glucose'].fillna(df1['Glucose'].median())

            print(df1.isnull().sum())
# Out:
#      <input type="file" id="files-32259496-5791-4207-8bc3-c456c83ebb47" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32259496-5791-4207-8bc3-c456c83ebb47">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
